# %%
import tensorflow as tf
import numpy as np
import sys

sys.path.insert(0, '../../')

from soundings.deep_learning import tf_neuralnetwork as nn

# %load_ext autoreload
# %autoreload 2

# %%
np.prod((16, 64))
# Out:
# 1024

# %%
n_rap_inputs = (256, 4)
n_im_inputs = [3, 3, 3]
n_hiddens_list = []
n_units_in_conv_layers = [16, 24, 32, 48, 64]
kernels_size_and_stride = [(3,1)]* len(n_units_in_conv_layers)
n_outputs = 512

nnet = nn.SkipNeuralNetwork(n_rap_inputs, n_im_inputs, n_hiddens_list,
                           n_units_in_conv_layers, kernels_size_and_stride,
                           n_outputs, dense_activation='tanh', dropout=False, seed=None)

# %%
tf.keras.utils.plot_model(nnet.model, show_shapes=True)

# %%
nnet.model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# rap (InputLayer)                [(None, 256, 4)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 256, 16)      208         rap[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 16)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# skip_conv1d_0 (Conv1D)          (None, 256, 16)      784         activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 16)      0           skip_conv1d_0[0][0]
# ...
